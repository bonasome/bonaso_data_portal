# %%
import psycopg2

# Replace with your actual database credentials
conn = psycopg2.connect(
    host="localhost",
    database="bonaso_data_database",
    user="postgres",
    password="Gorridean",
    port="5432"  # Optional, default is 5432
)
cur = conn.cursor()

# Execute a SQL query
cur.execute("SELECT * FROM respondents_interaction LEFT JOIN respondents_interactionsubcategory ON respondents_interaction.id = respondents_interactionsubcategory.interaction_id;")

# Fetch results
rows = cur.fetchall()

# Print or process the fetched data
for row in rows:
    print(row)
# Out:
# (1, datetime.date(2025, 8, 4), 1, datetime.datetime(2025, 8, 5, 8, 9, 47, 644459, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800))), 3, 3, datetime.datetime(2025, 8, 5, 8, 9, 47, 644484, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800))), None, None, None, 'There', None, 2, 1, 5, 1)
# (1, datetime.date(2025, 8, 4), 1, datetime.datetime(2025, 8, 5, 8, 9, 47, 644459, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800))), 3, 3, datetime.datetime(2025, 8, 5, 8, 9, 47, 644484, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800))), None, None, None, 'There', None, 1, 1, 4, 15)
# (2, datetime.date(2025, 8, 6), 1, datetime.datetime(2025, 8, 6, 7, 7, 7, 985033, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800))), 1, 3, datetime.datetime(2025, 8, 6, 7, 7, 7, 985082, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800))), None, None, None, 'There', None, 3, 2, 4, 3)
# ...
